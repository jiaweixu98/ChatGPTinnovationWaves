# %%
import pandas as pd

df1 = pd.read_csv('llm.csv')

df2 = pd.read_csv('semantic_scholar.csv')

result_df = pd.merge(df1, df2, on='title', how='inner')
# Out:
#             id_x                     submitter  \
# 0     1902.09097                     Joe Booth
# 1     1903.01669  Vijaya Sai Krishna Gottipati
# 2     1903.08855                 Nelson F. Liu
# 3     1903.09295            'Stephen' Zhen Gou
# 4     1903.11437                 Franck Burlot
# ...          ...                           ...
# 5093  2310.01432                    Zongjie Li
# 5094  2310.01434               Tom\'as Marques
# 5095  2310.01436                      Yang Gao
# 5096  2310.01441                    Hejia Geng
# 5097  2310.02277                        Lu Yin
#
#                                               authors_x  \
# 0                              Joe Booth, Jackson Booth
# 1     Sai Krishna, Keehong Seo, Dhaivat Bhatt, Vince...
# 2     Nelson F. Liu and Matt Gardner and Yonatan Bel...
# 3                          Stephen Zhen Gou, Yuyang Liu
# 4                   Franck Burlot and Fran\c{c}ois Yvon
# ...

# %%
result_df.to_csv('joined_dataset.csv',index = False)
