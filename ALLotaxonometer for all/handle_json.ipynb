# %%
import json
io = open("tree_species_counts@1.json","r")
dictionary = json.load(io)
print(dictionary)
# Out:
# {'1981-1983': [{'types': 'Pombalia prunifolia', 'counts': 39831, 'totalunique': 307, 'probs': 0.1692}, {'types': 'Faramea occidentalis', 'counts': 23444, 'totalunique': 307, 'probs': 0.0996}, {'types': 'Trichilia tuberculata', 'counts': 12925, 'totalunique': 307, 'probs': 0.0549}, {'types': 'Desmopsis panamensis', 'counts': 11711, 'totalunique': 307, 'probs': 0.0498}, {'types': 'Alseis blackiana', 'counts': 7599, 'totalunique': 307, 'probs': 0.0323}, {'types': 'Mouriri myrtilloides', 'counts': 6924, 'totalunique': 307, 'probs': 0.0294}, {'types': 'Psychotria horizontalis', 'counts': 6160, 'totalunique': 307, 'probs': 0.0262}, {'types': 'Hirtella triandra', 'counts': 4143, 'totalunique': 307, 'probs': 0.0176}, {'types': 'Garcinia recondita', 'counts': 3649, 'totalunique': 307, 'probs': 0.0155}, {'types': 'Capparidastrum frondosum', 'counts': 3536, 'totalunique': 307, 'probs': 0.015}, {'types': 'Poulsenia armata', 'counts': 3422, 'totalunique': 307, 'probs': 0.0145}, {'types': 'Sorocea
# ...

# %%
total_counts = 0
for i in dictionary['1981-1983']:
    total_counts += i['counts']

# %%
total_counts
# Out:
# 235341

# %%
s = json.dumps(dictionary)
open("out.json","w").write(s)
# Out:
# 206161
